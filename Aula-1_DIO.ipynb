# %%
import pandas as pd

# %%
df = pd.read_csv("aluguel.csv", sep=";")

# %%
df.head()
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
#
#     Valor  Condominio    IPTU
# 0  1700.0       500.0    60.0
# 1  7000.0         NaN     NaN
# 2  5200.0      4020.0  1111.0
# 3   800.0       390.0    20.0
# 4   800.0       230.0     NaN

# %%
df = df.rename(columns={"Tipo" : "Tipos"})
df
# Out:
#                          Tipos                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %%
df.head(15)
# Out:
#                       Tipos               Bairro  Quartos  Vagas  Suites  \
# 0                 Quitinete           Copacabana        1      0       0
# 1                      Casa      Jardim Botânico        2      0       1
# 2   Conjunto Comercial/Sala      Barra da Tijuca        0      4       0
# 3               Apartamento               Centro        1      0       0
# 4               Apartamento         Higienópolis        1      0       0
# 5               Apartamento         Vista Alegre        3      1       0
# 6               Apartamento             Cachambi        2      0       0
# 7        Casa de Condomínio      Barra da Tijuca        5      4       5
# 8        Casa de Condomínio                Ramos        2      2       0
# 9   Conjunto Comercial/Sala               Centro        0      3       0
# 10              Apartamento               Centro        1      0       0
# 11              Apartamento               Grajaú        2      1       0
# ...

# %%
df.shape
# Out:
# (32960, 9)

# %%
df.columns
# Out:
# Index(['Tipos', 'Bairro', 'Quartos', 'Vagas', 'Suites', 'Area', 'Valor',
#        'Condominio', 'IPTU'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Tipos          object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
df.tail()
# Out:
#                          Tipos                Bairro  Quartos  Vagas  Suites  \
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0

# %%
df.tail(20)
# Out:
#                          Tipos                    Bairro  Quartos  Vagas  \
# 32940              Apartamento           Barra da Tijuca        2      1
# 32941              Apartamento           Barra da Tijuca        3      2
# 32942  Conjunto Comercial/Sala           Barra da Tijuca        0      1
# 32943              Apartamento           Barra da Tijuca        3      2
# 32944              Apartamento  Recreio dos Bandeirantes        3      2
# 32945                Quitinete                Copacabana        1      0
# 32946  Conjunto Comercial/Sala                    Centro        0      0
# 32947              Apartamento                    Leblon        3      0
# 32948  Conjunto Comercial/Sala                    Centro        0      0
# 32949              Apartamento                   Ipanema        3      1
# 32950              Apartamento                    Tijuca        1      0
# 32951              Apartamento            Vila Valqueire        2      0
# ...

# %%
df.describe()
# Out:
#             Quartos         Vagas        Suites          Area         Valor  \
# count  32960.000000  32960.000000  32960.000000  32960.000000  3.294300e+04
# mean       1.771390      1.749059      0.665777    231.901547  1.295266e+04
# std        1.717869     20.380402      1.176525   1135.254152  6.675220e+05
# min        0.000000      0.000000      0.000000      0.000000  7.500000e+01
# 25%        0.000000      0.000000      0.000000     55.000000  1.500000e+03
# 50%        2.000000      1.000000      0.000000     87.000000  2.800000e+03
# 75%        3.000000      2.000000      1.000000    170.000000  6.500000e+03
# max      100.000000   1966.000000     70.000000  90000.000000  1.200000e+08
#
#          Condominio          IPTU
# count  2.886700e+04  2.272300e+04
# mean   2.388062e+03  2.364410e+03
# std    3.918496e+04  1.795641e+05
# min    1.000000e+00  1.000000e+00
# 25%    5.900000e+02  1.100000e+02
# 50%    9.900000e+02  2.500000e+02
# 75%    1.800000e+03  6.970000e+02
# ...

# %%
df["Tipos"].unique()
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
#filtro
casa = df.loc[df["Tipos"] == 'Casa']
casa.head()
# Out:
#     Tipos           Bairro  Quartos  Vagas  Suites  Area    Valor  Condominio  \
# 1    Casa  Jardim Botânico        2      0       1   100   7000.0         NaN
# 31   Casa     Campo Grande        4      1       2   400  12000.0         NaN
# 74   Casa            Méier        2      0       0    51   1500.0        50.0
# 82   Casa      São Conrado        4      2       4   730  28000.0      2000.0
# 138  Casa         Maracanã        8      3       5   259   7000.0         NaN
#
#         IPTU
# 1        NaN
# 31       NaN
# 74       NaN
# 82   12000.0
# 138      NaN

# %%
df.groupby("Bairro")["Tipos"].nunique()
# Out:
# Bairro
# Abolição              6
# Alto da Boa Vista     5
# Anchieta              6
# Andaraí               8
# Anil                  9
#                      ..
# Vila Valqueire        8
# Vila da Penha        10
# Vista Alegre          4
# Zumbi                 3
# Água Santa            4
# Name: Tipos, Length: 162, dtype: int64

# %%
df.groupby("Tipos")["Valor"].min()
# Out:
# Tipos
# Apartamento                       100.0
# Box/Garagem                        90.0
# Casa                              400.0
# Casa Comercial                    750.0
# Casa de Condomínio                560.0
# Casa de Vila                      380.0
# Chácara                          4900.0
# Conjunto Comercial/Sala            84.0
# Flat                              890.0
# Galpão/Depósito/Armazém            75.0
# Hotel                           12000.0
# Indústria                      120000.0
# Loft                              500.0
# Loja Shopping/ Ct Comercial       100.0
# Loja/Salão                        100.0
# Loteamento/Condomínio           11000.0
# Pousada/Chalé                    1480.0
# Prédio Inteiro                    100.0
# Quitinete                         100.0
# Studio                           1500.0
# Sítio                             990.0
# Terreno Padrão                   1000.0
# Name: Valor, dtype: float64
